# %%
from ultralytics import YOLO

model = YOLO(r"D:\hackathon\CodeXtremeHackathon\backend\Fruit_Detection_Project\fruit_tracer\core\ml_model\yolov8n.pt")  # Load YOLO model
model.train(data="D:\\hackathon\\CodeXtremeHackathon\\backend\\Fruit_Detection_Project\\fruit_dataset\\data.yaml", epochs=10, imgsz=640, batch=16, device="mps")
# Out:
# New https://pypi.org/project/ultralytics/8.3.81 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.80  Python-3.11.0 torch-2.6.0+cpu CPU (Intel Core(TM) i5-8250U 1.60GHz)
# ...
